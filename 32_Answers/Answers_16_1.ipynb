# %% [markdown]
# ### 18.13.1 Binary tree

# %% [markdown]
# 1. [Exercise 16.1.1 answer](Answers_16_1_01.ipynb)
# 1. [Exercise 16.1.2 answer](Answers_16_1_02.ipynb)

# %% [markdown]
# ⟵ [Previous section](Answers_14.ipynb) | [Up](32-introduction.ipynb)
